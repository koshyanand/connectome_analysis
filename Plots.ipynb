# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import igraph as ig
import networkx as nx
from utils import check_if_equal, create_adj_matrix, create_degree_dict,load_graph, get_labels, load_nx_graph

# %%
c_graph, h_graph = load_nx_graph()
# Out:
# Total number of different edges : 756

# %%
df_chimp_header, df_human_header = get_labels()


position = nx.circular_layout(h_graph) 
  
fig = plt.figure(figsize = (20, 20)) 
# # nx.draw_networkx(h_graph, pos) 

# # nx.draw_circular(h_graph, node_color='y', edge_color='#909090', node_size=500,labels=)
nx.draw_networkx_nodes(h_graph,position, nodelist=list(range(36)), node_size=500, node_color="b")
nx.draw_networkx_nodes(h_graph,position, nodelist=list(range(36, 72)), node_size=500, node_color="r")

nx.draw_networkx_edges(h_graph,position)
nx.draw_networkx_labels(h_graph,position)

plt.show()
fig.savefig('temp.png')
# plt.axis('equal')
# circPos=nx.circular_layout(cgraph)
# nx.draw_networkx_labels(cgraph,pos=circPos,labels=labels) 
# nx.draw(cgraph,pos=circPos)
