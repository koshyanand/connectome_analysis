# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import igraph as ig
import networkx as nx
from utils import get_max_flow,load_nx_graph, load_graph, create_array
from methods import get_centrality, get_tuple, get_label
import math
from networkx.algorithms import closeness_centrality
from networkx.algorithms.link_analysis.pagerank_alg import pagerank

# %%
chimp_graph, human_graph = load_nx_graph()
# Out:
# Total number of different edges : 756

# %%
print("pagerank")
c_values, arg_sorted_values, mean = get_centrality(chimp_graph, "pagerank", 5)
output = get_tuple(c_values, arg_sorted_values, True)
print(mean)
print(output)

h_values, arg_sorted_values, mean = get_centrality(human_graph, "pagerank", 5)
output = get_tuple(h_values, arg_sorted_values, False)
print(mean)
print(output)


plt.plot(list(range(1,73)), h_values, label = "Human")
plt.plot(list(range(1,73)), c_values, label = "Chimpanzee")
plt.xlabel('Node')
plt.ylabel('Pagerank Centrality')

plt.legend()
plt.savefig('pagerank.png')
plt.show()
# Out:
# edge_betweeness_centrality
# 1010
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-95a0084ed1ac> in <module>
#       1 print("edge_betweeness_centrality")
# ----> 2 c_values, arg_sorted_values, mean = get_centrality(chimp_graph, "edge_betweeness_centrality", 5)
#       3 print(c_values)
#       4 output = get_tuple(c_values, arg_sorted_values, True)
#       5 print(mean)
#
# ~/Desktop/courses/CS546/connectome_analysis/methods.py in get_centrality(graph, method, topk)
#      49         return
#      50     print(len(output))
# ---> 51     output = np.array(create_array(output))
#      52     mean = round(np.mean(output), 4)
#      53     if topk:
#
# ~/Desktop/courses/CS546/connectome_analysis/utils.py in create_array(dic)
#     104     out = []
#     105     for i in range(72):
# --> 106         out.append(dic[i])
#     107     return out
#
# KeyError: 0

# %%
ax = plt.gca()
ax.set_xscale("log")
ax.set_yscale("log")
degrees = np.array(human_graph.indegree())
inds_keep = np.where(degrees > 0)
ax.scatter(degrees[inds_keep], 
           pageranks[inds_keep])
plt.xlabel("degree")
plt.ylabel("pagerank")
plt.show()

# %%
# Out:
# Total number of different edges : 756
# 72
# 74.77777777777777
# 73.875
# [390.86011673 345.36771232 318.92124683 246.64671585 227.63481702]
# ['lFDp' 'lPEp' 'rPEp' 'lFE' 'rPEm']
# [687.58689832 551.41473176 308.42365789 301.13730896 200.65814972]
# ['lFDp' 'lPEp' 'rPEp' 'lFE' 'rPEm']
